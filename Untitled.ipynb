# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv("survey_results_public.csv")

# %%
df.head(5)
df.shape
# Out:
# (64461, 61)

# %%
df = df[["Country", "YearsCodePro", "Employment","ConvertedComp"]]
df = df.rename({"ConvertedComp": "Salary" }, axis=1) 
df.head(5)
df.shape
# Out:
# (64461, 4)

# %%
df = df[df["Salary"].notnull()]
df.head(5)
# Out:
#            Country YearsCodePro          Employment    Salary
# 7    United States           13  Employed full-time  116000.0
# 9   United Kingdom            4  Employed full-time   32315.0
# 10  United Kingdom            2  Employed full-time   40070.0
# 11           Spain            7  Employed full-time   14268.0
# 12     Netherlands           20  Employed full-time   38916.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34756 entries, 7 to 64154
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       34756 non-null  object
#  1   YearsCodePro  34621 non-null  object
#  2   Employment    34717 non-null  object
#  3   Salary        34756 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.3+ MB

# %%
df =df.dropna()
df.isnull().sum()

df.head(5)
# Out:
#            Country YearsCodePro          Employment    Salary
# 7    United States           13  Employed full-time  116000.0
# 9   United Kingdom            4  Employed full-time   32315.0
# 10  United Kingdom            2  Employed full-time   40070.0
# 11           Spain            7  Employed full-time   14268.0
# 12     Netherlands           20  Employed full-time   38916.0

# %%
df.shape
# Out:
# (34583, 4)

# %%
df1 = df[df["Employment"] == "Employment full-time"]
df1 = df.drop("Employment", axis=1)

# Printing the resulting DataFrame
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34583 entries, 7 to 64154
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       34583 non-null  object
#  1   YearsCodePro  34583 non-null  object
#  2   Salary        34583 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.1+ MB

# %%
df1.shape
df1.head(10)
# Out:
#            Country YearsCodePro     Salary
# 7    United States           13   116000.0
# 9   United Kingdom            4    32315.0
# 10  United Kingdom            2    40070.0
# 11           Spain            7    14268.0
# 12     Netherlands           20    38916.0
# 13   United States            1    66000.0
# 15  United Kingdom           23   108576.0
# 16   United States            3    79000.0
# 17   United States           12  1260000.0
# 18   United States            3    83400.0

# %%
df1["Country"].value_counts()
# Out:
# Country
# United States                       8133
# India                               2637
# United Kingdom                      2581
# Germany                             2298
# Canada                              1335
#                                     ...
# Monaco                                 1
# Saint Vincent and the Grenadines       1
# Niger                                  1
# Belize                                 1
# Yemen                                  1
# Name: count, Length: 159, dtype: int64

# %%
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categorical_map[categories.index[i]] = categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'Other'
    return categorical_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)
df.Country.value_counts()
# Out:
# Country
# Other                 10337
# United States          8133
# India                  2637
# United Kingdom         2581
# Germany                2298
# Canada                 1335
# Brazil                 1153
# France                 1123
# Netherlands             807
# Poland                  795
# Australia               770
# Spain                   759
# Italy                   661
# Russian Federation      614
# Sweden                  580
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary', 'Country' , ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()
